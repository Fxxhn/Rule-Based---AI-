# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sms-spam-collection-dataset/spam.csv

# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/sms-spam-collection-dataset/spam.csv", encoding='latin-1')
df = df[['v1', 'v2']]
df.columns = ['label', 'message']

spam_words = ['win', 'free', 'cash', 'prize', 'urgent', 'lottery']

def check_spam(msg):
    for word in spam_words:
        if word in msg.lower():
            return 'suspicious message'
    return 'normal message'

df['predicted_label'] = df['message'].apply(check_spam)
df.head(10)
# Out:
#   label                                            message     predicted_label
# 0   ham  Go until jurong point, crazy.. Available only ...      normal message
# 1   ham                      Ok lar... Joking wif u oni...      normal message
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...  suspicious message
# 3   ham  U dun say so early hor... U c already then say...      normal message
# 4   ham  Nah I don't think he goes to usf, he lives aro...      normal message
# 5  spam  FreeMsg Hey there darling it's been 3 week's n...  suspicious message
# 6   ham  Even my brother is not like to speak with me. ...      normal message
# 7   ham  As per your request 'Melle Melle (Oru Minnamin...      normal message
# 8  spam  WINNER!! As a valued network customer you have...  suspicious message
# 9  spam  Had your mobile 11 months or more? U R entitle...  suspicious message
